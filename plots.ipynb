# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Data

# %%
x = np.linspace(0, 1, 100).reshape((-1, 1))
a_vec = np.arange(1, 5)
y = np.exp(a_vec * x)

# %% [markdown]
# ### Default

# %%
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot1.png')

# %% [markdown]
# ### Vector graphics

# %%
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot2.pdf')

# %% [markdown]
# ### Font style

# %%
matplotlib.rcParams["text.usetex"] = True
matplotlib.rcParams["font.family"] = "serif"
matplotlib.rcParams["font.serif"] = "Computer Modern"
matplotlib.rcParams["font.size"] = 10

# %%
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot3.pdf')

# %% [markdown]
# ### Resize

# %%
def get_size(width=345.0, fraction=1.0):
    # Width of figure (in pts)
    fig_width_pt = width * fraction

    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    # https://disq.us/p/2940ij3
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio

    fig_dim = (fig_width_in, fig_height_in)

    return fig_dim

# %%
fig = plt.figure(figsize=get_size())
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot4.pdf')

# %% [markdown]
# ### Padding

# %%
matplotlib.rcParams["figure.constrained_layout.use"] = True
matplotlib.rcParams["figure.constrained_layout.h_pad"] = 0.005
matplotlib.rcParams["figure.constrained_layout.w_pad"] = 0.005
matplotlib.rcParams["figure.constrained_layout.hspace"] = 0.005
matplotlib.rcParams["figure.constrained_layout.wspace"] = 0.005

# %%
fig = plt.figure(figsize=get_size())
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot5.pdf')

# %% [markdown]
# ### Tick direction

# %%
matplotlib.rcParams["xtick.direction"] = "in"
matplotlib.rcParams["ytick.direction"] = "in"

# %%
fig = plt.figure(figsize=get_size())
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot6.pdf')

# %% [markdown]
# ### Fix legend

# %%
matplotlib.rcParams["legend.frameon"] = False
matplotlib.rcParams["legend.fontsize"] = 8

# %%
fig = plt.figure(figsize=get_size())
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot7.pdf')

# %% [markdown]
# ### Tex style

# %%
plt.style.use('tex')

# %%
fig = plt.figure(figsize=get_size())
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot8.pdf')

# %% [markdown]
# ### Seaborn style

# %%
plt.style.use('seaborn')
matplotlib.rcParams["text.usetex"] = True
matplotlib.rcParams["font.family"] = "serif"
matplotlib.rcParams["font.serif"] = "Computer Modern"
matplotlib.rcParams["font.size"] = 10
matplotlib.rcParams["legend.frameon"] = False
matplotlib.rcParams["legend.fontsize"] = 8

# %%
fig = plt.figure(figsize=get_size())
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot9.pdf')

# %% [markdown]
# ### Sciencestyle

# %%
# !pip install -qq SciencePlots

# %%
import scienceplots

# %%
plt.style.use('science')

# %%
fig = plt.figure(figsize=get_size())
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('value')
plt.title('$e^{ax}$')
plt.legend([f'{a = }' for a in a_vec])
plt.savefig('plot10.pdf')
